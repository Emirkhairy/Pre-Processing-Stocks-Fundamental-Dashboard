# %% [markdown]
# ---------

# %%
# Import Library

import pandas as pd
from yahoofinancials import YahooFinancials
pd.set_option('max_columns', None)

# %%
# import related data and assinged to df
df=pd.read_excel('All IDX Stocks.xlsx')
df
# Out:
#      Unnamed: 0 Ticker with .JK
# 0             0         BIPI.JK
# 1             1         ENRG.JK
# 2             2         MEDC.JK
# 3             3         MITI.JK
# 4             4         SUGI.JK
# ..          ...             ...
# 798         798         SDMU.JK
# 799         799         SMDR.JK
# 800         800         TMAS.JK
# 801         801         TNCA.JK
# 802         802         TRUK.JK
#
# [803 rows x 2 columns]

# %%
df=df.iloc[:,1:2]
df
# Out:
#     Ticker with .JK
# 0           BIPI.JK
# 1           ENRG.JK
# 2           MEDC.JK
# 3           MITI.JK
# 4           SUGI.JK
# ..              ...
# 798         SDMU.JK
# 799         SMDR.JK
# 800         TMAS.JK
# 801         TNCA.JK
# 802         TRUK.JK
#
# [803 rows x 1 columns]

# %%
ticker=df['Ticker with .JK'].tolist()
ticker
# Out:
# ['BIPI.JK',
#  'ENRG.JK',
#  'MEDC.JK',
#  'MITI.JK',
#  'SUGI.JK',
#  'SURE.JK',
#  'AKRA.JK',
#  'BULL.JK',
#  'GTSI.JK',
#  'HITS.JK',
#  'INPS.JK',
#  'KOPI.JK',
#  'LEAD.JK',
#  'MTFN.JK',
#  'PGAS.JK',
#  'RAJA.JK',
#  'SHIP.JK',
#  'SOCI.JK',
#  'ADMR.JK',
#  'ADRO.JK',
#  'AIMS.JK',
#  'ARII.JK',
#  'BOSS.JK',
#  'BSSR.JK',
#  'BUMI.JK',
#  'BYAN.JK',
#  'DSSA.JK',
#  'GEMS.JK',
#  'GTBO.JK',
#  'HRUM.JK',
#  'INDY.JK',
#  'ITMG.JK',
#  'KKGI.JK',
#  'MBAP.JK',
#  'MCOL.JK',
#  'PTBA.JK',
#  'SMMT.JK',
#  'TOBA.JK',
#  'TRAM.JK',
#  'BBRM.JK',
#  'BESS.JK',
#  'BSML.JK',
#  'CANI.JK',
#  'CNKO.JK',
#  'DWGL.JK',
#  'FIRE.JK',
#  'MBSS.JK',
#  'PSSI.JK',
#  'PTIS.JK',
#  'RIGS.JK',
#  'RMKE.JK',
#  'SGER.JK',
#  'TCPI.JK',
#  'TEBE.JK',
#  'TPMA.JK',
#  'APEX.JK',
#  'ELSA.JK',
#  'ARTI.JK',
#  'DEWA.JK',
#  'DOID.JK',
#  'ITMA.JK',
#  'MYOH.JK',
#  'PKPK.JK',
#  'PTRO.JK',
#  'RUIS.JK',
#  'SICO.JK',
#  'SMRU.JK',
#  'TAMU.JK',
#  'UNIQ.JK',
#  'WINS.JK',
#  'WOWS.JK',
# ...

# %% [markdown]
# -------

# %%
# Assinged the ticker data to yahoofinance to get financial data
yahoo_financials = YahooFinancials(ticker)
data_used=yahoo_financials.get_key_statistics_data()
# Out:
# WARNING:root:yahoofinancials ticker: SUGI.JK error getting keystats - <class 'yahoofinancials.etl.ManagedException'>
# 	Continuing extraction...
# WARNING:root:yahoofinancials ticker: TRAM.JK error getting keystats - <class 'yahoofinancials.etl.ManagedException'>
# 	Continuing extraction...
# WARNING:root:yahoofinancials ticker: SMRU.JK error getting keystats - <class 'yahoofinancials.etl.ManagedException'>
# 	Continuing extraction...
# WARNING:root:yahoofinancials ticker: JKSW.JK error getting keystats - <class 'yahoofinancials.etl.ManagedException'>
# 	Continuing extraction...
# WARNING:root:yahoofinancials ticker: SIMA.JK error getting keystats - <class 'yahoofinancials.etl.ManagedException'>
# 	Continuing extraction...
# WARNING:root:yahoofinancials ticker: KBRI.JK error getting keystats - <class 'yahoofinancials.etl.ManagedException'>
# 	Continuing extraction...
# ...

# %%
new_data =pd.read_excel('Data Yfinance.xlsx')
new_data
# Out:
#      Unnamed: 0    Stock    Market Cap      Beta       BV          P/BV  \
# 0           NaN      NaN           NaN       NaN      NaN           NaN
# 1           0.0  BIPI.JK  5.426750e+10  0.495231    0.007  20571.428000
# 2           1.0  ENRG.JK  2.482120e+10  0.863760    0.024   9250.000000
# 3           2.0  MEDC.JK  2.502530e+10  1.539850    0.062  15000.000000
# 4           3.0  MITI.JK  3.540740e+09 -0.182561   75.699      2.100424
# ..          ...      ...           ...       ...      ...           ...
# 777       776.0  SDMU.JK  1.135220e+09       NaN   -0.614           NaN
# 778       777.0  SMDR.JK  1.637560e+10       NaN    0.035  10800.000000
# 779       778.0  TMAS.JK  5.688750e+09  0.218664  430.385      6.645213
# 780       779.0  TNCA.JK  4.216400e+08  0.519301  102.672      2.668693
# 781       780.0  TRUK.JK  0.000000e+00  0.203509  125.132      0.727232
#
#       EV/EBITDA
# 0           NaN
# 1    244582.380
# 2     13392.456
# 3     15934.374
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  781 non-null    float64
#  1   Stock       781 non-null    object
#  2   Market Cap  753 non-null    float64
#  3   Beta        504 non-null    float64
#  4   BV          754 non-null    float64
#  5   P/BV        714 non-null    float64
#  6   EV/EBITDA   523 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 42.9+ KB

# %%
#EDA
new_data.duplicated().sum()
# Out:
# 0

# %%
# took some industry sector data
Industry = pd.read_excel('Sektor Industry.xlsx')

# %%
Industry
# Out:
#      Unnamed: 0 Ticker with .JK                 Major Sektor Industri  \
# 0             0         BIPI.JK                    Energy (IDXENERGY)
# 1             1         ENRG.JK                    Energy (IDXENERGY)
# 2             2         MEDC.JK                    Energy (IDXENERGY)
# 3             3         MITI.JK                    Energy (IDXENERGY)
# 4             4         SUGI.JK                    Energy (IDXENERGY)
# ..          ...             ...                                   ...
# 798         798         SDMU.JK  Transportation & Logistic (IDXTRANS)
# 799         799         SMDR.JK  Transportation & Logistic (IDXTRANS)
# 800         800         TMAS.JK  Transportation & Logistic (IDXTRANS)
# 801         801         TNCA.JK  Transportation & Logistic (IDXTRANS)
# 802         802         TRUK.JK  Transportation & Logistic (IDXTRANS)
#
#             Sektor Industri
# 0          Oil, Gas, & Coal
# 1          Oil, Gas, & Coal
# 2          Oil, Gas, & Coal
# ...

# %%
Industry.drop(Industry.columns[0], axis=1, inplace =True)
Industry.rename(columns={'Ticker with .JK': 'Stock'}, inplace = True)

# %%
df_new=new_data.merge(Industry, on ='Stock')
df_new.drop(df_new.columns[0],axis=1,inplace= True)
df_new
# Out:
#        Stock    Market Cap      Beta       BV          P/BV   EV/EBITDA  \
# 0    BIPI.JK  5.426750e+10  0.495231    0.007  20571.428000  244582.380
# 1    ENRG.JK  2.482120e+10  0.863760    0.024   9250.000000   13392.456
# 2    MEDC.JK  2.502530e+10  1.539850    0.062  15000.000000   15934.374
# 3    MITI.JK  3.540740e+09 -0.182561   75.699      2.100424      32.695
# 4    SUGI.JK           NaN       NaN      NaN           NaN         NaN
# ..       ...           ...       ...      ...           ...         ...
# 798  SDMU.JK  1.135220e+09       NaN   -0.614           NaN         NaN
# 799  SMDR.JK  1.637560e+10       NaN    0.035  10800.000000   16638.918
# 800  TMAS.JK  5.688750e+09  0.218664  430.385      6.645213       9.682
# 801  TNCA.JK  4.216400e+08  0.519301  102.672      2.668693      70.252
# 802  TRUK.JK  0.000000e+00  0.203509  125.132      0.727232      15.651
#
#                     Major Sektor Industri         Sektor Industri
# ...

# %%
# Import file to Excel to run it on tableau
df_new.to_excel('Data Dashboard.xlsx')
